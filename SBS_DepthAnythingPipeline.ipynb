# %% [markdown]
# # SBS 3D Video Generation Pipeline
#
# This notebook outlines the process of converting a monocular video into a side-by-side (SBS) 3D video.

# %% [markdown]
# ## Setup and Preparation
#
# Import necessary libraries and define the input video path.
#
# Personally, I opt for the file structure `datasets/d{index}/[set of input/output folder for frames]`

# %%
import timeit
import os
import subprocess

dataset = 1
# Define the path to the input video
dataset_directory = f'datasets/d{dataset}/'
input_video_path = dataset_directory + 'test.mp4'
final_video_filename = dataset_directory + 'test_SBS.mp4'

# %% [markdown]
# ## Import and Setup Depth Anything Project

# %% [markdown]
# Run depth anything model for video input, specify if wishing to include depth model locally

# %%
local_path = False
local_path_directory = "your_local_directory"
current_working_directory = os.getcwd()

# %%
if local_path:
    local_path_directory = r"depth_models"
    # Clone the repository
    os.system("git clone https://github.com/LiheYoung/Depth-Anything")
    # Change directory to the cloned repository
    os.chdir("Depth-Anything")
    # Create a Conda environment named 'depth-anything' with Python 3.11
    os.system("conda create -n depth-anything python=3.11")
    # Activate the Conda environment
    os.system("conda activate depth-anything")
    # Install PyTorch and other dependencies
    os.system("conda install pytorch torchvision torchaudio pytorch-cuda=11.8 -c pytorch -c nvidia")
    # Install additional Python packages from requirements.txt
    os.system("pip install -r requirements.txt")
    # Print a message to indicate successful setup
    print("Project setup complete.")

# %%
# if not local path, specify remote path for depth-anything
remote_path = r"..\Depth-Anything"
if not local_path: local_path_directory = remote_path
print(f"Path set {local_path_directory}")
# Out:
# Path set ..\Depth-Anything

# %%
def checkPath(path):
    if os.path.exists(path): print(f"The file '{path}' exists.")
    else: print(f"The file '{path}' does not exist.")

# %%
rgbd_frames = dataset_directory + 'rgbd_in/'
os.makedirs(rgbd_frames, exist_ok=True)

print(f"dataset directory {dataset_directory}\n video dire {input_video_path}\n outdir {dataset_directory}")
print(f"local path {local_path_directory}")

# Check if the file exists
file_path = os.path.join(local_path_directory, "run_depth_only.py")

# Get the current working directory
current_working_directory = os.getcwd()

# Define the full paths to input video and dataset directory
input_video_path_full = os.path.join(current_working_directory, input_video_path)
dataset_directory_full = os.path.join(current_working_directory, dataset_directory)
checkPath(input_video_path_full)
checkPath(dataset_directory_full)


os.chdir(local_path_directory)
# !python {local_path_directory}/run_depth_only.py --encoder vitl --video-path {input_video_path_full} --outdir {dataset_directory_full}
# Out:
# dataset directory datasets/d1/
#  video dire datasets/d1/test.mp4
#  outdir datasets/d1/
# local path ..\Depth-Anything
# The file 'C:\Users\abahrema\Documents\Tools\sbs-generator\datasets/d1/test.mp4' exists.
# The file 'C:\Users\abahrema\Documents\Tools\sbs-generator\datasets/d1/' exists.
# Cuda available? True
# Model directory C:\Users\abahrema\Documents\Tools\Depth-Anything\checkpoints\depth_anything_vitb14
# Loading weights from local directory
# Total parameters: 97.47M
# Progress 1/1, Processing C:\Users\abahrema\Documents\Tools\sbs-generator\datasets/d1/test.mp4
# xFormers not available
# xFormers not available

# %% [markdown]
# ## Extract Frames from Video
#
# Use ffmpeg to extract frames from the input color video and depth video.

# %%
# switch directory back
output_depth_video = dataset_directory + "test_video_depth.mp4"
os.chdir(current_working_directory)
print(f"Changed directory to {current_working_directory}")
# Out:
# Changed directory to C:\Users\abahrema\Documents\Tools\sbs-generator

# %%
# Create directory if non-existent
output_frames_path = dataset_directory + 'rgbd_in/frame%d.jpg'
output_dir = os.path.dirname(output_frames_path)
os.makedirs(output_dir, exist_ok=True)
print(f"output_frames_path: {output_frames_path}, output_dir: {output_dir}")
print(f"video {input_video_path}")
# execute ffmpeg command for color
# !ffmpeg -i {input_video_path} -q:v 2 {output_frames_path} 
output_frames_path = dataset_directory + 'rgbd_in/frame%d.png' # for depth
# !ffmpeg -i {output_depth_video} -q:v 2 {output_frames_path}
# Out:
# output_frames_path: datasets/d1/rgbd_in/frame%d.jpg, output_dir: datasets/d1/rgbd_in
# video datasets/d1/test.mp4
# ffmpeg version 2024-01-28-git-e0da916b8f-full_build-www.gyan.dev Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.2.0 (Rev10, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --pkg-config=pkgconf --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-sdl2 --enable-libaribb24 --enable-libaribcaption --enable-libdav1d --enable-libdavs2 --enable-libuavs3d --enable-libzvbi --enable-librav1e --enable-libsvtav1 --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxvid --enable-libaom --enable-libjxl --enable-libopenjpeg --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-ffnvcodec --enable-nvdec --enable-nvenc --enable-dxva2 --enable-d3d11va --enable-libvpl --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libcodec2 --enable-libilbc --enable-libgsm --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint
#   libavutil      58. 36.101 / 58. 36.101
#   libavcodec     60. 38.100 / 60. 38.100
#   libavformat    60. 20.100 / 60. 20.100
#   libavdevice    60.  4.100 / 60.  4.100
#   libavfilter     9. 17.100 /  9. 17.100
#   libswscale      7.  6.100 /  7.  6.100
#   libswresample   4. 13.100 /  4. 13.100
#   libpostproc    57.  4.100 / 57.  4.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'datasets/d1/test.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf59.27.100
#   Duration: 00:00:03.33, start: 0.000000, bitrate: 18297 kb/s
#   Stream #0:0[0x1](und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 1920x1080 [SAR 1:1 DAR 16:9], 18294 kb/s, 24 fps, 24 tbr, 12288 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 00000193243d4340] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to 'datasets/d1/rgbd_in/frame%d.jpg':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf60.20.100
#   Stream #0:0(und): Video: mjpeg, yuvj420p(pc, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 24 fps, 24 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc60.38.100 mjpeg
#       Side data:
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# [out#0/image2 @ 0000019321a40e40] video:30696kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# frame=   80 fps=0.0 q=2.0 Lsize=N/A time=00:00:03.33 bitrate=N/A speed=8.74x
# ffmpeg version 2024-01-28-git-e0da916b8f-full_build-www.gyan.dev Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.2.0 (Rev10, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --pkg-config=pkgconf --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-sdl2 --enable-libaribb24 --enable-libaribcaption --enable-libdav1d --enable-libdavs2 --enable-libuavs3d --enable-libzvbi --enable-librav1e --enable-libsvtav1 --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxvid --enable-libaom --enable-libjxl --enable-libopenjpeg --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-ffnvcodec --enable-nvdec --enable-nvenc --enable-dxva2 --enable-d3d11va --enable-libvpl --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libcodec2 --enable-libilbc --enable-libgsm --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint
#   libavutil      58. 36.101 / 58. 36.101
#   libavcodec     60. 38.100 / 60. 38.100
#   libavformat    60. 20.100 / 60. 20.100
#   libavdevice    60.  4.100 / 60.  4.100
#   libavfilter     9. 17.100 /  9. 17.100
#   libswscale      7.  6.100 /  7.  6.100
#   libswresample   4. 13.100 /  4. 13.100
#   libpostproc    57.  4.100 / 57.  4.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'datasets/d1/test_video_depth.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:03.33, start: 0.000000, bitrate: 3903 kb/s
#   Stream #0:0[0x1](und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 1920x1080 [SAR 1:1 DAR 16:9], 3900 kb/s, 24 fps, 24 tbr, 12288 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to 'datasets/d1/rgbd_in/frame%d.png':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf60.20.100
#   Stream #0:0(und): Video: png, rgb24(pc, gbr/unknown/unknown, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 24 fps, 24 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc60.38.100 png
# frame=   23 fps=0.0 q=-0.0 size=N/A time=00:00:01.20 bitrate=N/A speed=2.21x
# [out#0/image2 @ 00000188cbf4fa40] video:36691kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# frame=   80 fps=0.0 q=-0.0 Lsize=N/A time=00:00:03.33 bitrate=N/A speed=3.65x

# %% [markdown]
# ## Image Preprocessing
#
# Rename and pair color and depth images as needed. Run the script or run the function inside notebook.

# %%
rgbd_frames = dataset_directory + 'rgbd_in/'
# Example for renaming images (adjust according to your script)
# !python sbs_rename_directory.py {rgbd_frames}

# %%
import os
import re

def get_frame_number(filename):
    match = re.search(r"frame(\d+)_", filename)
    if match:
        return int(match.group(1))
    else:
        raise ValueError(f"Invalid filename format: {filename}")
        
def rename_files(source_dir):
    os.makedirs(source_dir, exist_ok=True)

    # Process color images
    color_files = sorted([f for f in os.listdir(source_dir) if f.startswith("frame") and f.endswith(".jpg")], 
                         key=lambda x: int(x.split("frame")[1].split(".")[0]))
    counter = 1
    for filename in color_files:
        new_name = f"color{counter}.jpg"
        os.rename(os.path.join(source_dir, filename), os.path.join(source_dir, new_name))
        counter += 1
    print(f"Renamed {counter} color files in {source_dir}.")

    # Process depth images
    depth_files = sorted([f for f in os.listdir(source_dir) if f.startswith("frame") and f.endswith(".png")], 
                         key=lambda x: int(x.split("frame")[1].split(".")[0]))
    counter = 1
    for filename in depth_files:
        new_name = f"depth{counter}.png"
        os.rename(os.path.join(source_dir, filename), os.path.join(source_dir, new_name))
        counter += 1
    print(f"Renamed {counter} depth files in {source_dir}.")
    
source_dir = dataset_directory + "rgbd_in/"
rename_files(source_dir)
# Out:
# Renamed 81 color files in datasets/d1/rgbd_in/.
# Renamed 81 depth files in datasets/d1/rgbd_in/.

# %% [markdown]
# ## Generate Stereo Views
#
# Run the script to generate left and right eye views or run the function inside notebook.

# %%
stereo_input_dir =  dataset_directory + "rgbd_in/"
stereo_output_dir = dataset_directory + "stereo_out_frames/"
os.makedirs(stereo_input_dir, exist_ok=True)
os.makedirs(stereo_output_dir, exist_ok=True)

# !python sbs_generate_stereoviews.py {stereo_input_dir} {stereo_output_dir}

# %%
import os
import cv2
import numpy as np
import os
import concurrent.futures

def shift_pixels(image, depth_map, direction, scale_factor, shift_threshold, frame_name, output_dir):
    height, width = image.shape[:2]
    disparity_map = (depth_map.astype(np.float32) * scale_factor).astype(np.int32)

    # Generate mesh for coordinates
    x_coords, y_coords = np.meshgrid(np.arange(width), np.arange(height))

    # Calculate new x coordinates
    new_x_coords = x_coords + (disparity_map * direction)

    # Initialize shifted image with zeros (black)
    shifted_image = np.zeros_like(image)

    # Calculate valid mask where new x coordinates are within image bounds
    valid_mask = (new_x_coords >= 0) & (new_x_coords < width)

    # Apply valid shifts to shifted_image
    valid_y, valid_x = np.where(valid_mask)
    new_valid_x_coords = new_x_coords[valid_y, valid_x]
    shifted_image[valid_y, new_valid_x_coords] = image[valid_y, valid_x]

    # Find significant shifts where disparity is greater than or equal to the shift threshold
    significant_mask = (np.abs(disparity_map) >= shift_threshold) & valid_mask
    significant_y, significant_x = np.where(significant_mask)

    # Correct new_x based on direction for significant pixels
    significant_new_x = significant_x + (disparity_map[significant_y, significant_x] * direction)

    # Keep only the significant shifts that are within bounds
    in_bounds_mask = (significant_new_x >= 0) & (significant_new_x < width)
    significant_new_x = significant_new_x[in_bounds_mask]
    significant_y = significant_y[in_bounds_mask]

    # Convert 2D coordinates to linear indices using new_x for the x-coordinate
    significant_shift_indexes = np.ravel_multi_index((significant_y, significant_new_x), dims=(height, width))
    # np.save(os.path.join(output_dir, f"{frame_name}_{direction}_significant_shifts.npy"), significant_shift_indexes)
    
    return shifted_image, significant_shift_indexes


# The rest of the process_image_pair function and the execution code remain unchanged.
def process_image_pair(args):
    color_image_path, depth_image_path, output_dir, frame_number, scale_factor, shift_threshold = args
    print(f"Processing frame {frame_number}")
    print(f"Processing frame {frame_number}")

    # Load the color image and depth map
    color_image = cv2.imread(color_image_path)
    depth_map = cv2.imread(depth_image_path, cv2.IMREAD_UNCHANGED)

    # Check if the images are loaded correctly
    if color_image is None:
        raise ValueError(f"Color image for frame {frame_number} could not be loaded from {color_image_path}")
    if depth_map is None:
        raise ValueError(f"Depth image for frame {frame_number} could not be loaded from {depth_image_path}")

    # Convert depth_map to grayscale if necessary
    if depth_map.ndim == 3:
        depth_map = cv2.cvtColor(depth_map, cv2.COLOR_BGR2GRAY)

    frame_name = os.path.splitext(os.path.basename(color_image_path))[0]
    left_eye_image, left_mask = shift_pixels(color_image, depth_map, 1, scale_factor, shift_threshold, frame_name, output_dir)
    right_eye_image, right_mask = shift_pixels(color_image, depth_map, -1, scale_factor, shift_threshold, frame_name, output_dir)

    # Check if the shifted images are valid
    if left_eye_image is None:
        raise ValueError(f"Left eye image processing failed for frame {frame_number}")
    if right_eye_image is None:
        raise ValueError(f"Right eye image processing failed for frame {frame_number}")

    # Ensure output directories exist
    left_eye_dir = os.path.join(output_dir, 'leftEye')
    right_eye_dir = os.path.join(output_dir, 'rightEye')
    os.makedirs(left_eye_dir, exist_ok=True)
    os.makedirs(right_eye_dir, exist_ok=True)

    # Save the processed images
    left_eye_output_path = os.path.join(left_eye_dir, f'leftEye{frame_number}.jpg')
    right_eye_output_path = os.path.join(right_eye_dir, f'rightEye{frame_number}.jpg')
    left_eye_mask_path = os.path.join(left_eye_dir, f'leftEyeMask{frame_number}.npy')
    right_eye_mask_path = os.path.join(right_eye_dir, f'rightEyeMask{frame_number}.npy')
    if not cv2.imwrite(left_eye_output_path, left_eye_image):
        raise ValueError(f"Failed to save left eye image for frame {frame_number} at {left_eye_output_path}")
    if not cv2.imwrite(right_eye_output_path, right_eye_image):
        raise ValueError(f"Failed to save right eye image for frame {frame_number} at {right_eye_output_path}")
    # if not np.save(left_eye_mask_path, left_mask):
    #     raise ValueError(f"Failed to save left eye image for frame {frame_number} at {left_eye_output_path}")
    # if not np.save(right_eye_mask_path, right_mask):
    #     raise ValueError(f"Failed to save right eye image for frame {frame_number} at {right_eye_output_path}")
    np.save(left_eye_mask_path, left_mask)
    np.save(right_eye_mask_path, right_mask)
    print(f"Saved processed images for frame {frame_number}")

def parallel_process_images(input_directory, output_directory, scale_factor, shift_threshold):
    os.makedirs(output_directory, exist_ok=True)

    color_images = sorted([f for f in os.listdir(input_directory) if f.startswith('color')])
    depth_images = sorted([f for f in os.listdir(input_directory) if f.startswith('depth')])
    frame_numbers = range(1, len(color_images))  # Assuming frame numbering starts at 1

    # Prepare arguments for each call to process_image_pair
    tasks = [(os.path.join(input_directory, color_images[i-1]),
              os.path.join(input_directory, depth_images[i-1]),
              output_directory, i, scale_factor, shift_threshold) for i in frame_numbers]

    # Using ThreadPoolExecutor to process images in parallel
    with concurrent.futures.ThreadPoolExecutor(max_workers=os.cpu_count() - 1) as executor:
        futures = [executor.submit(process_image_pair, task) for task in tasks]
        
        # Optionally, handle exceptions and results
        for future in concurrent.futures.as_completed(futures):
            try:
                future.result()  # Or print result if your function returns anything
            except Exception as e:
                print(f"An error occurred: {e}")
        # list(tqdm(concurrent.futures.as_completed(futures), total=len(futures)))
    print("Image processing completed.")


# Setup directories
input_directory = f"{dataset_directory}/rgbd_in"
output_directory = f"{dataset_directory}/stereo"
os.makedirs(output_directory, exist_ok=True)
scale_factor = 0.1
shift_threshold = 1
# Call the parallel processing function
parallel_process_images(input_directory, output_directory, scale_factor, shift_threshold)

print("Image processing completed.")
# Out:
# Processing frame 1
# Processing frame 1
# Processing frame 2
# Processing frame 2
# Processing frame 3
# Processing frame 3
# Processing frame 4
# Processing frame 4
# Processing frame 5
# Processing frame 5
# Processing frame 6
# Processing frame 6
# Processing frame 7
# Processing frame 7
# Processing frame 8
# Processing frame 8
# Processing frame 9
# Processing frame 9
# Processing frame 10
# Processing frame 10
# Processing frame 11
# Processing frame 11
# Processing frame 12
# Processing frame 12
# Processing frame 13
# Processing frame 13
# Processing frame 14
# Processing frame 14
# Processing frame 15
# Processing frame 15
# Processing frame 16
# Processing frame 16
# Processing frame 17
# Processing frame 17
# Processing frame 18
# Processing frame 18
# Processing frame 19
# Processing frame 19
# Saved processed images for frame 5
# Processing frame 20
# Processing frame 20
# Saved processed images for frame 6
# Processing frame 21
# Processing frame 21
# Saved processed images for frame 7
# Processing frame 22
# Processing frame 22
# Saved processed images for frame 12
# Processing frame 23
# Processing frame 23
# Saved processed images for frame 13
# Processing frame 24
# Processing frame 24
# Saved processed images for frame 9
# Processing frame 25
# Processing frame 25
# Saved processed images for frame 1
# Processing frame 26
# Processing frame 26
# Saved processed images for frame 2Saved processed images for frame 3
# Processing frame 27
# Processing frame 27
#
# Processing frame 28
# Processing frame 28
# Saved processed images for frame 18
# Processing frame 29
# Processing frame 29
# Saved processed images for frame 4
# Processing frame 30
# Processing frame 30
# Saved processed images for frame 19
# Processing frame 31
# Processing frame 31
# Saved processed images for frame 8
# Processing frame 32
# Processing frame 32
# Saved processed images for frame 15
# Processing frame 33
# Processing frame 33
# Saved processed images for frame 10
# Processing frame 34
# Processing frame 34
# Saved processed images for frame 14
# Processing frame 35
# Processing frame 35
# Saved processed images for frame 17
# Processing frame 36
# Processing frame 36
# Saved processed images for frame 20
# Processing frame 37
# Processing frame 37
# Saved processed images for frame 16
# Processing frame 38
# Processing frame 38
# Saved processed images for frame 11
# Processing frame 39
# Processing frame 39
# Saved processed images for frame 23
# Processing frame 40
# Processing frame 40
# Saved processed images for frame 21
# Processing frame 41
# Processing frame 41
# Saved processed images for frame 24
# Processing frame 42
# Processing frame 42
# Saved processed images for frame 22
# Processing frame 43
# Processing frame 43
# Saved processed images for frame 37
# Processing frame 44
# Processing frame 44
# Saved processed images for frame 40
# Processing frame 45
# Processing frame 45
# Saved processed images for frame 41
# Processing frame 46
# Processing frame 46
# Saved processed images for frame 25
# Processing frame 47
# Processing frame 47
# Saved processed images for frame 42
# Processing frame 48
# Processing frame 48
# Saved processed images for frame 26
# Processing frame 49
# Processing frame 49
# Saved processed images for frame 31
# Processing frame 50
# Processing frame 50
# Saved processed images for frame 29
# Processing frame 51
# Processing frame 51
# Saved processed images for frame 43
# Processing frame 52
# Processing frame 52
# Saved processed images for frame 30
# Processing frame 53
# Processing frame 53
# Saved processed images for frame 27
# Processing frame 54
# Processing frame 54
# Saved processed images for frame 28
# Processing frame 55
# Processing frame 55
# Saved processed images for frame 33
# Processing frame 56
# Processing frame 56
# Saved processed images for frame 44
# Processing frame 57
# Processing frame 57
# Saved processed images for frame 32
# Processing frame 58
# Processing frame 58
# Saved processed images for frame 45
# Processing frame 59
# Processing frame 59
# Saved processed images for frame 39
# Processing frame 60
# Processing frame 60
# Saved processed images for frame 38
# Processing frame 61
# Processing frame 61
# Saved processed images for frame 46
# Processing frame 62
# Processing frame 62
# Saved processed images for frame 36
# Processing frame 63
# Processing frame 63
# Saved processed images for frame 34
# Processing frame 64
# Processing frame 64
# Saved processed images for frame 35
# Processing frame 65
# Processing frame 65
# Saved processed images for frame 48
# Processing frame 66
# Processing frame 66
# Saved processed images for frame 52
# Processing frame 67
# Processing frame 67
# Saved processed images for frame 57
# Processing frame 68
# Processing frame 68
# Saved processed images for frame 47
# Processing frame 69
# Processing frame 69
# Saved processed images for frame 59
# Processing frame 70
# Processing frame 70
# Saved processed images for frame 62
# Processing frame 71
# Processing frame 71
# Saved processed images for frame 49
# Processing frame 72
# Processing frame 72
# Saved processed images for frame 53
# Processing frame 73
# Processing frame 73
# Saved processed images for frame 51
# Processing frame 74
# Processing frame 74
# Saved processed images for frame 54
# Processing frame 75
# Processing frame 75
# Saved processed images for frame 50
# Processing frame 76
# Processing frame 76
# Saved processed images for frame 66
# Processing frame 77
# Processing frame 77
# Saved processed images for frame 63
# Processing frame 78
# Processing frame 78
# Saved processed images for frame 60
# Processing frame 79
# Processing frame 79
# Saved processed images for frame 56
# Saved processed images for frame 68
# Saved processed images for frame 55
# Saved processed images for frame 61
# Saved processed images for frame 58
# Saved processed images for frame 71
# Saved processed images for frame 67
# Saved processed images for frame 64
# Saved processed images for frame 65
# Saved processed images for frame 70
# Saved processed images for frame 69
# Saved processed images for frame 72
# Saved processed images for frame 77
# Saved processed images for frame 73
# Saved processed images for frame 76
# Saved processed images for frame 74
# Saved processed images for frame 75
# Saved processed images for frame 78
# Saved processed images for frame 79
# Image processing completed.
# Image processing completed.

# %%
# %time

import cv2
import numpy as np
import os

def process_images(input_dir, output_dir, scale_factor):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    color_images = sorted([f for f in os.listdir(input_dir) if f.startswith('color')])
    depth_images = sorted([f for f in os.listdir(input_dir) if f.startswith('depth')])

    for color_image_path, depth_image_path in zip(color_images, depth_images):
        color_image = cv2.imread(os.path.join(input_dir, color_image_path))
        depth_map = cv2.imread(os.path.join(input_dir, depth_image_path), cv2.IMREAD_GRAYSCALE)

        if color_image is None:
            print(f"Error: Color image not found at {os.path.join(input_dir, color_image_path)}")
            continue

        if depth_map is None:
            print(f"Error: Depth map not found at {os.path.join(input_dir, depth_image_path)}")
            continue

        # Function to shift pixels based on depth map
        def shift_pixels(image, depth_map, direction):
            shifted_image = np.zeros_like(image)
            for y in range(image.shape[0]):
                for x in range(image.shape[1]):
                    disparity = calculate_disparity(depth_map[y, x])
                    new_x = x + disparity * direction
                    if 0 <= new_x < image.shape[1]:
                        shifted_image[y, new_x] = image[y, x]
            return shifted_image

        # Calculate disparity (example function, adjust as needed)
        def calculate_disparity(depth_value):
            # Simple linear mapping, adjust the scale factor as needed
            return int(depth_value * scale_factor)

        # Create left and right eye images
        left_eye_image = shift_pixels(color_image, depth_map, 1)
        right_eye_image = shift_pixels(color_image, depth_map, -1)

        frame_number = color_image_path.split('color')[1].split('.')[0]
        
        if not os.path.exists(os.path.join(output_dir,'leftEye')):
            os.makedirs(os.path.join(output_dir,'leftEye'))
        if not os.path.exists(os.path.join(output_dir,'rightEye')):
            os.makedirs(os.path.join(output_dir,'rightEye'))
        
        left_eye_output_path = os.path.join(output_dir, f'leftEye/leftEye{frame_number}.jpg')
        right_eye_output_path = os.path.join(output_dir, f'rightEye/rightEye{frame_number}.jpg')

        # Save the left and right eye images
        cv2.imwrite(left_eye_output_path, left_eye_image)
        cv2.imwrite(right_eye_output_path, right_eye_image)

        print(f"Processed frame {frame_number}.")

# Example usage
stereo_input_dir =  dataset_directory + "rgbd_in/"
stereo_output_dir = dataset_directory + "stereo_out_frames/"
os.makedirs(stereo_input_dir, exist_ok=True)
os.makedirs(stereo_output_dir, exist_ok=True)
process_images(stereo_input_dir, stereo_output_dir, 0.05)

# %% [markdown]
# ## Inpainting Process
#
# Run the script for inpainting left and right eye images or run the function inside notebook.

# %%
stereo_output_dir = dataset_directory + "stereo/"
stereo_postprocess_dir = dataset_directory + "stereo_post/"
os.makedirs(stereo_output_dir, exist_ok=True)
os.makedirs(stereo_postprocess_dir, exist_ok=True)

# !python sbs_inpaint_stereoviews.py {stereo_output_dir} {stereo_postprocess_dir}

# %%
import cv2
import numpy as np
import os
import concurrent.futures
from skimage import io, color
from skimage.morphology import binary_dilation, disk


def create_img_mask(color_image, black_pixels_npy_path):
    # print(f"np path {black_pixels_npy_path}")
    # Load the black pixel indexes from the npy file
    black_pixel_indexes = np.load(black_pixels_npy_path)
    
    # Initialize the mask image with zeros (all black)
    mask_image = np.zeros(color_image.shape[:2], dtype=np.uint8)
    
    # Image dimensions
    height, width = color_image.shape[:2]
    
    # Check the shape of the loaded indexes and convert if necessary
    if black_pixel_indexes.ndim == 1:
        # Convert linear indices to 2D coordinates
        y_coords, x_coords = np.divmod(black_pixel_indexes, width)
    else:
        # Assuming the array is already in the form of (y, x) pairs
        y_coords, x_coords = black_pixel_indexes[:, 0], black_pixel_indexes[:, 1]
    
    # Mark the black pixels in the mask image
    mask_image[y_coords, x_coords] = 255  # Mark as white in the mask
    return mask_image
    
def inpaint_image_with_mask(color_image, mask, inpaint_radius=3):
    """
    Inpaints a color image using a mask image.

    Parameters:
    - color_image_path: Path to the color image.
    - mask_image_path: Path to the mask image where white pixels indicate areas to inpaint.
    - inpaint_radius: Radius of a circular neighborhood of each point inpainted that is considered by the algorithm.

    Returns:
    - inpainted_image: The inpainted image as a NumPy array.
    """    
    # Load the color image and mask
    # color_image = cv2.imread(color_image_path)
    # mask = cv2.imread(mask_image_path, cv2.IMREAD_GRAYSCALE)

    # Ensure the mask is binary
    # _, mask_binary = cv2.threshold(mask, 127, 255, cv2.THRESH_BINARY)
    # mask_binary = cv2.adaptiveThreshold(mask, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY_INV, 3, 8)
    mask_binary = cv2.adaptiveThreshold(mask, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY_INV, 3, 8)
    # Perform inpainting
    print("about to perform inpaint operation")
    # inpainted_image = cv2.inpaint(color_image, mask_binary, inpaint_radius, cv2.INPAINT_TELEA)
    inpainted_image = cv2.inpaint(color_image, mask_binary, 3, cv2.INPAINT_TELEA)

    # Convert image to grayscale
    gray_image = color.rgb2gray(inpainted_image)
    threshold = 0.05  # A value close to 0 to capture black
    binary_mask = gray_image < threshold    
    # Dilate the mask to ensure all black or near black pixels are included
    dilated_mask = binary_dilation(binary_mask, disk(1))    
    inpainted_image = cv2.inpaint(inpainted_image, dilated_mask.astype(np.uint8), 3, cv2.INPAINT_TELEA)
    print("inpaint complete")
    return inpainted_image

def process_single_pair(left_eye_image_path, right_eye_image_path, left_eye_mask_path, right_eye_mask_path, output_dir, save_masks=True):
    # Read the images
    left_eye_image = cv2.imread(left_eye_image_path)
    right_eye_image = cv2.imread(right_eye_image_path)

    if left_eye_image is None or right_eye_image is None:
        print(f"Error: Image not found at {left_eye_image_path} or {right_eye_image_path}")
        return

    # Extract frame number from the image path
    frame_number = os.path.basename(left_eye_image_path).split('leftEye')[1].split('.')[0]

   # Paths for saving masks should use os.path.join to avoid path separator issues
    left_eye_mask_dir = os.path.join(output_dir, 'leftEye')
    right_eye_mask_dir = os.path.join(output_dir, 'rightEye')
    os.makedirs(left_eye_mask_dir, exist_ok=True)
    os.makedirs(right_eye_mask_dir, exist_ok=True)
    
    left_eye_mask_output_path = os.path.join(left_eye_mask_dir, f'leftEyeMask{frame_number}.jpg')
    right_eye_mask_output_path = os.path.join(right_eye_mask_dir, f'rightEyeMask{frame_number}.jpg')
    left_eye_inpaint_output_path = os.path.join(left_eye_mask_dir, f'leftEyeInpaint{frame_number}.jpg')
    right_eye_inpaint_output_path = os.path.join(right_eye_mask_dir, f'rightEyeInpaint{frame_number}.jpg')

    if save_masks:
        # left_eye_mask_path = left_eye_mask_dir + r"/leftEyeMask" + str(frame_number) + '.npy'
        # right_eye_mask_path = right_eye_mask_dir + r"/rightEyeMask" + str(frame_number) + '.npy'
        # print(f"left {left_eye_mask_output_path} right {right_eye_mask_output_path}")
        # Create masks for the black streaks in both left and right eye images
        left_eye_mask = create_img_mask(left_eye_image, left_eye_mask_path)    
        right_eye_mask = create_img_mask(right_eye_image, right_eye_mask_path)    

        left_eye_inpaint = inpaint_image_with_mask(left_eye_image, left_eye_mask)
        right_eye_inpaint = inpaint_image_with_mask(right_eye_image, right_eye_mask)
        # Save the masks
        cv2.imwrite(left_eye_mask_output_path, left_eye_mask)
        cv2.imwrite(right_eye_mask_output_path, right_eye_mask)
        cv2.imwrite(left_eye_inpaint_output_path, left_eye_inpaint)
        cv2.imwrite(right_eye_inpaint_output_path, right_eye_inpaint)
        

    print(f"Processed frame {frame_number}, {left_eye_mask_output_path}")


def process_images(input_dir, output_dir, save_masks=True):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)


    left_path = os.path.join(input_dir, "leftEye")
    right_path = os.path.join(input_dir, "rightEye")
    
    # Get sorted list of image paths
    left_eye_images = sorted([os.path.join(left_path, f) for f in os.listdir(left_path) if f.startswith('leftEye')])
    right_eye_images = sorted([os.path.join(right_path, f) for f in os.listdir(right_path) if f.startswith('rightEye')])
    left_eye_masks = sorted([os.path.join(left_path, f) for f in os.listdir(left_path) if f.startswith('leftEyeMask')])
    right_eye_masks = sorted([os.path.join(right_path, f) for f in os.listdir(right_path) if f.startswith('rightEyeMask')])
    # Process images in parallel
    with concurrent.futures.ThreadPoolExecutor(max_workers=os.cpu_count() - 1) as executor:
        # Submit tasks to the executor
        tasks = {
            executor.submit(process_single_pair, left_eye_image_path, right_eye_image_path, left_eye_mask_path, right_eye_mask_path, output_dir, save_masks): (left_eye_image_path, right_eye_image_path, left_eye_mask_path, right_eye_mask_path)
            for left_eye_image_path, right_eye_image_path, left_eye_mask_path, right_eye_mask_path in zip(left_eye_images, right_eye_images, left_eye_masks, right_eye_masks)
        }

        # Wait for all tasks to complete
        for future in concurrent.futures.as_completed(tasks):
            # You can add error checking here if you like
            try:
                future.result()
            except Exception as e:
                left_eye_image_path, right_eye_image_path = tasks[future]
                print(f"Exception processing {left_eye_image_path} and {right_eye_image_path}: {e}")
        # list(tqdm(concurrent.futures.as_completed(futures), total=len(futures)))
    print("Image processing completed.")


# Setup directories
input_directory = f"{dataset_directory}/stereo/"
output_directory = f"{dataset_directory}/stereo_post/"
os.makedirs(output_directory, exist_ok=True)

# Iterate over the input directory and process pairs
process_images(input_directory, output_directory)
print("Image processing completed.")
# Out:
# about to perform inpaint operationabout to perform inpaint operation
#
# about to perform inpaint operation
# about to perform inpaint operation
# about to perform inpaint operation
# about to perform inpaint operation
# about to perform inpaint operation
# about to perform inpaint operation
# about to perform inpaint operation
# about to perform inpaint operation
# about to perform inpaint operation
# about to perform inpaint operation
# about to perform inpaint operation
# about to perform inpaint operation
# about to perform inpaint operation
# about to perform inpaint operation
# about to perform inpaint operation
# about to perform inpaint operation
# about to perform inpaint operation
# inpaint complete
# about to perform inpaint operation
# inpaint complete
# about to perform inpaint operation
# inpaint complete
# about to perform inpaint operation
# inpaint complete
# about to perform inpaint operation
# inpaint complete
# Processed frame 12, datasets/d1//stereo_post/leftEye\leftEyeMask12.jpg
# inpaint complete
# about to perform inpaint operation
# inpaint complete
# about to perform inpaint operation
# Processed frame 1, datasets/d1//stereo_post/leftEye\leftEyeMask1.jpg
# inpaint complete
# about to perform inpaint operation
# inpaint complete
# Processed frame 19, datasets/d1//stereo_post/leftEye\leftEyeMask19.jpg
# about to perform inpaint operation
# about to perform inpaint operation
# inpaint complete
# inpaint complete
# about to perform inpaint operation
# Processed frame 18, datasets/d1//stereo_post/leftEye\leftEyeMask18.jpg
# inpaint complete
# about to perform inpaint operation
# about to perform inpaint operation
# inpaint complete
# about to perform inpaint operation
# inpaint completeinpaint complete
#
# about to perform inpaint operation
# about to perform inpaint operation
# inpaint complete
# about to perform inpaint operation
# inpaint complete
# about to perform inpaint operation
# inpaint complete
# about to perform inpaint operation
# inpaint complete
# about to perform inpaint operation
# inpaint complete
# about to perform inpaint operation
# inpaint complete
# about to perform inpaint operation
# inpaint complete
# Processed frame 23, datasets/d1//stereo_post/leftEye\leftEyeMask23.jpg
# inpaint complete
# about to perform inpaint operation
# inpaint complete
# about to perform inpaint operation
# about to perform inpaint operation
# inpaint complete
# about to perform inpaint operation
# inpaint complete
# inpaint complete
# about to perform inpaint operation
# inpaint complete
# inpaint complete
# inpaint complete
# Processed frame 27, datasets/d1//stereo_post/leftEye\leftEyeMask27.jpg
# Processed frame 13, datasets/d1//stereo_post/leftEye\leftEyeMask13.jpg
# Processed frame 20, datasets/d1//stereo_post/leftEye\leftEyeMask20.jpg
# Processed frame 29, datasets/d1//stereo_post/leftEye\leftEyeMask29.jpg
# about to perform inpaint operation
# about to perform inpaint operation
# inpaint complete
# about to perform inpaint operation
# about to perform inpaint operation
# about to perform inpaint operation
# inpaint complete
# about to perform inpaint operation
# inpaint complete
# about to perform inpaint operation
# inpaint complete
# Processed frame 31, datasets/d1//stereo_post/leftEye\leftEyeMask31.jpg
# inpaint complete
# about to perform inpaint operation
# inpaint complete
# inpaint complete
# about to perform inpaint operation
# Processed frame 21, datasets/d1//stereo_post/leftEye\leftEyeMask21.jpg
# Processed frame 2, datasets/d1//stereo_post/leftEye\leftEyeMask2.jpg
# about to perform inpaint operation
# about to perform inpaint operation
# inpaint complete
# inpaint complete
# Processed frame 14, datasets/d1//stereo_post/leftEye\leftEyeMask14.jpg
# Processed frame 32, datasets/d1//stereo_post/leftEye\leftEyeMask32.jpg
# about to perform inpaint operation
# about to perform inpaint operation
# inpaint complete
# about to perform inpaint operation
# inpaint complete
# inpaint complete
# Processed frame 34, datasets/d1//stereo_post/leftEye\leftEyeMask34.jpg
# inpaint completeabout to perform inpaint operation
#
# about to perform inpaint operation
# Processed frame 22, datasets/d1//stereo_post/leftEye\leftEyeMask22.jpg
# about to perform inpaint operation
# inpaint complete
# about to perform inpaint operation
# inpaint complete
# about to perform inpaint operation
# inpaint complete
# about to perform inpaint operation
# inpaint complete
# Processed frame 10, datasets/d1//stereo_post/leftEye\leftEyeMask10.jpg
# about to perform inpaint operation
# inpaint complete
# Processed frame 35, datasets/d1//stereo_post/leftEye\leftEyeMask35.jpg
# about to perform inpaint operation
# inpaint complete
# about to perform inpaint operation
# inpaint complete
# about to perform inpaint operation
# inpaint complete
# inpaint complete
# about to perform inpaint operation
# Processed frame 28, datasets/d1//stereo_post/leftEye\leftEyeMask28.jpg
# inpaint complete
# about to perform inpaint operation
# inpaint complete
# inpaint complete
# about to perform inpaint operation
# Processed frame 11, datasets/d1//stereo_post/leftEye\leftEyeMask11.jpg
# Processed frame 24, datasets/d1//stereo_post/leftEye\leftEyeMask24.jpg
# about to perform inpaint operation
# about to perform inpaint operation
# inpaint complete
# Processed frame 37, datasets/d1//stereo_post/leftEye\leftEyeMask37.jpg
# inpaint complete
# about to perform inpaint operation
# about to perform inpaint operation
# inpaint complete
# inpaint complete
# about to perform inpaint operation
# Processed frame 25, datasets/d1//stereo_post/leftEye\leftEyeMask25.jpg
# inpaint complete
# inpaint complete
# about to perform inpaint operation
# about to perform inpaint operation
# Processed frame 33, datasets/d1//stereo_post/leftEye\leftEyeMask33.jpg
# inpaint complete
# Processed frame 39, datasets/d1//stereo_post/leftEye\leftEyeMask39.jpg
# about to perform inpaint operation
# about to perform inpaint operation
# inpaint complete
# Processed frame 4, datasets/d1//stereo_post/leftEye\leftEyeMask4.jpg
# inpaint complete
# about to perform inpaint operation
# Processed frame 38, datasets/d1//stereo_post/leftEye\leftEyeMask38.jpg
# inpaint complete
# inpaint complete
# inpaint complete
# about to perform inpaint operation
# Processed frame 46, datasets/d1//stereo_post/leftEye\leftEyeMask46.jpg
# inpaint complete
# about to perform inpaint operation
# inpaint complete
# about to perform inpaint operation
# about to perform inpaint operation
# Processed frame 44, datasets/d1//stereo_post/leftEye\leftEyeMask44.jpg
# Processed frame 26, datasets/d1//stereo_post/leftEye\leftEyeMask26.jpg
# inpaint complete
# inpaint complete
# inpaint complete
# about to perform inpaint operation
# about to perform inpaint operation
# about to perform inpaint operation
# Processed frame 15, datasets/d1//stereo_post/leftEye\leftEyeMask15.jpg
# Processed frame 30, datasets/d1//stereo_post/leftEye\leftEyeMask30.jpg
# inpaint complete
# inpaint complete
# Processed frame 5, datasets/d1//stereo_post/leftEye\leftEyeMask5.jpg
# about to perform inpaint operation
# about to perform inpaint operation
# about to perform inpaint operation
# inpaint complete
# about to perform inpaint operation
# Processed frame 16, datasets/d1//stereo_post/leftEye\leftEyeMask16.jpg
# inpaint complete
# about to perform inpaint operation
# about to perform inpaint operation
# inpaint complete
# Processed frame 42, datasets/d1//stereo_post/leftEye\leftEyeMask42.jpg
# inpaint complete
# about to perform inpaint operation
# inpaint complete
# inpaint complete
# about to perform inpaint operation
# inpaint complete
# about to perform inpaint operation
# about to perform inpaint operation
# Processed frame 17, datasets/d1//stereo_post/leftEye\leftEyeMask17.jpg
# inpaint complete
# about to perform inpaint operation
# inpaint complete
# about to perform inpaint operation
# about to perform inpaint operation
# inpaint complete
# about to perform inpaint operation
# inpaint complete
# Processed frame 49, datasets/d1//stereo_post/leftEye\leftEyeMask49.jpg
# inpaint complete
# about to perform inpaint operation
# Processed frame 58, datasets/d1//stereo_post/leftEye\leftEyeMask58.jpg
# about to perform inpaint operation
# inpaint complete
# inpaint complete
# about to perform inpaint operation
# inpaint complete
# about to perform inpaint operation
# inpaint complete
# inpaint complete
# about to perform inpaint operation
# Processed frame 3, datasets/d1//stereo_post/leftEye\leftEyeMask3.jpg
# Processed frame 36, datasets/d1//stereo_post/leftEye\leftEyeMask36.jpg
# inpaint complete
# about to perform inpaint operation
# about to perform inpaint operation
# about to perform inpaint operation
# inpaint complete
# about to perform inpaint operation
# inpaint complete
# about to perform inpaint operation
# inpaint complete
# inpaint complete
# about to perform inpaint operation
# inpaint complete
# Processed frame 45, datasets/d1//stereo_post/leftEye\leftEyeMask45.jpg
# Processed frame 56, datasets/d1//stereo_post/leftEye\leftEyeMask56.jpg
# inpaint complete
# about to perform inpaint operation
# inpaint complete
# about to perform inpaint operation
# inpaint complete
# about to perform inpaint operation
# about to perform inpaint operation
# Processed frame 6, datasets/d1//stereo_post/leftEye\leftEyeMask6.jpg
# about to perform inpaint operation
# inpaint complete
# Processed frame 47, datasets/d1//stereo_post/leftEye\leftEyeMask47.jpg
# inpaint complete
# inpaint complete
# about to perform inpaint operation
# Processed frame 50, datasets/d1//stereo_post/leftEye\leftEyeMask50.jpg
# Processed frame 51, datasets/d1//stereo_post/leftEye\leftEyeMask51.jpg
# about to perform inpaint operation
# about to perform inpaint operation
# inpaint complete
# about to perform inpaint operation
# inpaint complete
# about to perform inpaint operation
# inpaint complete
# inpaint complete
# inpaint complete
# about to perform inpaint operation
# Processed frame 60, datasets/d1//stereo_post/leftEye\leftEyeMask60.jpg
# inpaint complete
# about to perform inpaint operation
# Processed frame 59, datasets/d1//stereo_post/leftEye\leftEyeMask59.jpg
# about to perform inpaint operation
# inpaint complete
# about to perform inpaint operation
# Processed frame 48, datasets/d1//stereo_post/leftEye\leftEyeMask48.jpg
# inpaint complete
# about to perform inpaint operation
# about to perform inpaint operation
# inpaint complete
# about to perform inpaint operation
# inpaint complete
# inpaint complete
# about to perform inpaint operation
# about to perform inpaint operation
# inpaint complete
# inpaint complete
# about to perform inpaint operation
# Processed frame 40, datasets/d1//stereo_post/leftEye\leftEyeMask40.jpg
# about to perform inpaint operation
# inpaint complete
# about to perform inpaint operation
# inpaint complete
# about to perform inpaint operation
# inpaint complete
# inpaint complete
# about to perform inpaint operation
# Processed frame 41, datasets/d1//stereo_post/leftEye\leftEyeMask41.jpg
# inpaint complete
# inpaint complete
# inpaint complete
# inpaint complete
# about to perform inpaint operation
# Processed frame 65, datasets/d1//stereo_post/leftEye\leftEyeMask65.jpg
# Processed frame 68, datasets/d1//stereo_post/leftEye\leftEyeMask68.jpg
# Processed frame 64, datasets/d1//stereo_post/leftEye\leftEyeMask64.jpg
# Processed frame 69, datasets/d1//stereo_post/leftEye\leftEyeMask69.jpg
# about to perform inpaint operation
# about to perform inpaint operation
# about to perform inpaint operation
# about to perform inpaint operation
# inpaint complete
# inpaint complete
# Processed frame 61, datasets/d1//stereo_post/leftEye\leftEyeMask61.jpg
# inpaint complete
# Processed frame 52, datasets/d1//stereo_post/leftEye\leftEyeMask52.jpg
# about to perform inpaint operation
# Processed frame 71, datasets/d1//stereo_post/leftEye\leftEyeMask71.jpg
# about to perform inpaint operation
# inpaint complete
# inpaint complete
# inpaint complete
# Processed frame 67, datasets/d1//stereo_post/leftEye\leftEyeMask67.jpg
# about to perform inpaint operation
# about to perform inpaint operation
# inpaint complete
# about to perform inpaint operation
# inpaint complete
# Processed frame 43, datasets/d1//stereo_post/leftEye\leftEyeMask43.jpg
# inpaint complete
# about to perform inpaint operation
# inpaint complete
# Processed frame 7, datasets/d1//stereo_post/leftEye\leftEyeMask7.jpg
# about to perform inpaint operation
# Processed frame 53, datasets/d1//stereo_post/leftEye\leftEyeMask53.jpg
# inpaint complete
# about to perform inpaint operation
# inpaint complete
# about to perform inpaint operation
# Processed frame 62, datasets/d1//stereo_post/leftEye\leftEyeMask62.jpg
# inpaint complete
# about to perform inpaint operation
# inpaint complete
# inpaint complete
# Processed frame 55, datasets/d1//stereo_post/leftEye\leftEyeMask55.jpg
# Processed frame 54, datasets/d1//stereo_post/leftEye\leftEyeMask54.jpg
# inpaint complete
# inpaint complete
# Processed frame 57, datasets/d1//stereo_post/leftEye\leftEyeMask57.jpg
# Processed frame 66, datasets/d1//stereo_post/leftEye\leftEyeMask66.jpg
# inpaint complete
# Processed frame 63, datasets/d1//stereo_post/leftEye\leftEyeMask63.jpg
# inpaint complete
# inpaint complete
# about to perform inpaint operation
# Processed frame 70, datasets/d1//stereo_post/leftEye\leftEyeMask70.jpg
# inpaint complete
# about to perform inpaint operation
# inpaint complete
# about to perform inpaint operation
# inpaint complete
# Processed frame 72, datasets/d1//stereo_post/leftEye\leftEyeMask72.jpg
# inpaint complete
# about to perform inpaint operation
# inpaint complete
# about to perform inpaint operation
# inpaint complete
# Processed frame 73, datasets/d1//stereo_post/leftEye\leftEyeMask73.jpg
# inpaint complete
# inpaint complete
# Processed frame 74, datasets/d1//stereo_post/leftEye\leftEyeMask74.jpg
# Processed frame 8, datasets/d1//stereo_post/leftEye\leftEyeMask8.jpg
# inpaint complete
# Processed frame 75, datasets/d1//stereo_post/leftEye\leftEyeMask75.jpg
# inpaint complete
# Processed frame 76, datasets/d1//stereo_post/leftEye\leftEyeMask76.jpg
# inpaint complete
# Processed frame 9, datasets/d1//stereo_post/leftEye\leftEyeMask9.jpg
# inpaint complete
# Processed frame 78, datasets/d1//stereo_post/leftEye\leftEyeMask78.jpg
# inpaint complete
# Processed frame 77, datasets/d1//stereo_post/leftEye\leftEyeMask77.jpg
# inpaint complete
# Processed frame 79, datasets/d1//stereo_post/leftEye\leftEyeMask79.jpg
# Image processing completed.
# Image processing completed.

# %%
import cv2
import numpy as np
import os

def create_mask_for_black_streaks(image):
    # Convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    # Use adaptive thresholding to better capture the black streaks
    mask = cv2.adaptiveThreshold(gray, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY_INV, 3, 8)
    
    # Dilate the mask to include the edges of the black streaks
    kernel = np.ones((5,5), np.uint8)
    mask = cv2.dilate(mask, kernel, iterations=1)
    
    return mask

def inpaint_black_streaks(image, mask):
    # Inpaint the black streaks in the image
    inpainted_image = cv2.inpaint(image, mask, 5, cv2.INPAINT_TELEA)
    
    return inpainted_image

def process_images(input_dir, output_dir, save_masks=False):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    if not os.path.exists(os.path.join(output_dir,'leftEye')):
        os.makedirs(os.path.join(output_dir,'leftEye'))
    if not os.path.exists(os.path.join(output_dir,'rightEye')):
        os.makedirs(os.path.join(output_dir,'rightEye'))
    
    if save_masks:
        if not os.path.exists(os.path.join(output_dir,'leftEyeMask')):
            os.makedirs(os.path.join(output_dir,'leftEyeMask'))
        if not os.path.exists(os.path.join(output_dir,'rightEyeMask')):
            os.makedirs(os.path.join(output_dir,'rightEyeMask'))

    left_path = input_dir + "leftEye/"
    right_path = input_dir + "rightEye/"
    left_eye_images = sorted([f for f in os.listdir(left_path) if f.startswith('leftEye')])
    right_eye_images = sorted([f for f in os.listdir(right_path) if f.startswith('rightEye')])

    for left_eye_image_path, right_eye_image_path in zip(left_eye_images, right_eye_images):
        left_eye_image = cv2.imread(os.path.join(left_path, left_eye_image_path))
        right_eye_image = cv2.imread(os.path.join(right_path, right_eye_image_path))

        if left_eye_image is None or right_eye_image is None:
            print(f"Error: Image not found at {os.path.join(input_dir, left_eye_image_path)} or {os.path.join(input_dir, right_eye_image_path)}")
            continue

        # Create masks for the black streaks in both left and right eye images
        left_eye_mask = create_mask_for_black_streaks(left_eye_image)
        right_eye_mask = create_mask_for_black_streaks(right_eye_image)

        # Inpaint the black streaks in both left and right eye images
        # left_eye_post = inpaint_black_streaks(left_eye_image, left_eye_mask)
        # right_eye_post = inpaint_black_streaks(right_eye_image, right_eye_mask)

        frame_number = left_eye_image_path.split('leftEye')[1].split('.')[0]
        left_eye_post_output_path = os.path.join(output_dir + "leftEye/", f'leftEyePost{frame_number}.jpg')
        right_eye_post_output_path = os.path.join(output_dir + "rightEye/", f'rightEyePost{frame_number}.jpg')
        # Save the processed images and masks
        # cv2.imwrite(left_eye_post_output_path, left_eye_post)
        # cv2.imwrite(right_eye_post_output_path, right_eye_post)
        
        if (save_masks):
            left_eye_mask_output_path = os.path.join(output_dir + "leftEyeMask/", f'leftEyeMask{frame_number}.jpg')
            right_eye_mask_output_path = os.path.join(output_dir + "rightEyeMask/", f'rightEyeMask{frame_number}.jpg')
            cv2.imwrite(left_eye_mask_output_path, left_eye_mask)
            cv2.imwrite(right_eye_mask_output_path, right_eye_mask)

        print(f"Processed frame {frame_number}.")

                          
stereo_output_dir = dataset_directory + "stereo_out_frames/"
stereo_postprocess_dir = dataset_directory + "stereo_postprocess_frames/"
os.makedirs(stereo_output_dir, exist_ok=True)
os.makedirs(stereo_postprocess_dir, exist_ok=True)                          
# Example usage
process_images(stereo_output_dir, stereo_postprocess_dir)

# %% [markdown]
# ## Create Videos from Images
#
# Use ffmpeg to create left and right eye videos.
#
# **Note** what the appropriate frame rate should be based on your input video.

# %%
left_eye_dir = dataset_directory + "stereo_post/" + "leftEye/"
right_eye_dir = dataset_directory + "stereo_post/" + "rightEye/"
os.makedirs(left_eye_dir, exist_ok=True)
os.makedirs(right_eye_dir, exist_ok=True)
left_eye_dir += "leftEyeInpaint%d.jpg" # "leftEyePost%d.jpg"
right_eye_dir +=  "rightEyeInpaint%d.jpg" # "rightEyePost%d.jpg"

left_eye_vid = dataset_directory + "left_eye.mp4"
right_eye_vid = dataset_directory + "right_eye.mp4"


# !ffmpeg -framerate 24 -i {left_eye_dir} -c:v libx264 -pix_fmt yuv420p -vf "fps=24" {left_eye_vid}
# !ffmpeg -framerate 24 -i {right_eye_dir} -c:v libx264 -pix_fmt yuv420p -vf "fps=24" {right_eye_vid}
# Out:
# ffmpeg version 2024-01-28-git-e0da916b8f-full_build-www.gyan.dev Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.2.0 (Rev10, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --pkg-config=pkgconf --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-sdl2 --enable-libaribb24 --enable-libaribcaption --enable-libdav1d --enable-libdavs2 --enable-libuavs3d --enable-libzvbi --enable-librav1e --enable-libsvtav1 --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxvid --enable-libaom --enable-libjxl --enable-libopenjpeg --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-ffnvcodec --enable-nvdec --enable-nvenc --enable-dxva2 --enable-d3d11va --enable-libvpl --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libcodec2 --enable-libilbc --enable-libgsm --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint
#   libavutil      58. 36.101 / 58. 36.101
#   libavcodec     60. 38.100 / 60. 38.100
#   libavformat    60. 20.100 / 60. 20.100
#   libavdevice    60.  4.100 / 60.  4.100
#   libavfilter     9. 17.100 /  9. 17.100
#   libswscale      7.  6.100 /  7.  6.100
#   libswresample   4. 13.100 /  4. 13.100
#   libpostproc    57.  4.100 / 57.  4.100
# Input #0, image2, from 'datasets/d1/stereo_post/leftEye/leftEyeInpaint%d.jpg':
#   Duration: 00:00:03.29, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 1920x1080 [SAR 1:1 DAR 16:9], 24 fps, 24 tbr, 24 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 000001e0d649c700] deprecated pixel format used, make sure you did set range correctly
#     Last message repeated 3 times
# [libx264 @ 000001e0d60d5800] using SAR=1/1
# [libx264 @ 000001e0d60d5800] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 000001e0d60d5800] profile High, level 4.0, 4:2:0, 8-bit
# [libx264 @ 000001e0d60d5800] 264 - core 164 r3173 4815cca - H.264/MPEG-4 AVC codec - Copyleft 2003-2024 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=30 lookahead_threads=5 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'datasets/d1/left_eye.mp4':
#   Metadata:
#     encoder         : Lavf60.20.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 24 fps, 12288 tbn
#       Metadata:
#         encoder         : Lavc60.38.100 libx264
#       Side data:
#         cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=    0 fps=0.0 q=0.0 size=       0kB time=N/A bitrate=N/A speed=N/A
# frame=    0 fps=0.0 q=0.0 size=       0kB time=N/A bitrate=N/A speed=N/A
# frame=   23 fps= 15 q=28.0 size=    1024kB time=00:00:00.87 bitrate=9587.4kbits/s speed=0.56x
# frame=   56 fps= 27 q=-1.0 size=    2816kB time=00:00:02.25 bitrate=10252.9kbits/s speed=1.08x
# [out#0/mp4 @ 000001e0d6233bc0] video:4449kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.039929%
# frame=   79 fps= 35 q=-1.0 Lsize=    4451kB time=00:00:03.20 bitrate=11364.0kbits/s speed=1.41x
# [libx264 @ 000001e0d60d5800] frame I:1     Avg QP:25.98  size:161419
# [libx264 @ 000001e0d60d5800] frame P:38    Avg QP:25.35  size: 74685
# [libx264 @ 000001e0d60d5800] frame B:40    Avg QP:28.61  size: 38887
# [libx264 @ 000001e0d60d5800] consecutive B-frames: 16.5% 45.6%  7.6% 30.4%
# [libx264 @ 000001e0d60d5800] mb I  I16..4:  2.2% 87.8% 10.0%
# [libx264 @ 000001e0d60d5800] mb P  I16..4:  0.2%  6.3%  0.9%  P16..4: 41.9% 31.7% 15.1%  0.0%  0.0%    skip: 4.0%
# [libx264 @ 000001e0d60d5800] mb B  I16..4:  0.4% 11.7%  2.1%  B16..8: 43.7% 10.7%  2.2%  direct: 2.8%  skip:26.5%  L0:39.7% L1:46.3% BI:14.0%
# [libx264 @ 000001e0d60d5800] 8x8 transform intra:83.7% inter:68.2%
# [libx264 @ 000001e0d60d5800] coded y,uvDC,uvAC intra: 86.3% 98.7% 82.0% inter: 34.3% 49.5% 8.7%
# [libx264 @ 000001e0d60d5800] i16 v,h,dc,p: 17% 26% 20% 37%
# [libx264 @ 000001e0d60d5800] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 14% 19% 14%  7%  9%  7% 11%  7% 13%
# [libx264 @ 000001e0d60d5800] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 14% 21% 10%  8% 11%  8% 12%  6% 10%
# [libx264 @ 000001e0d60d5800] i8c dc,h,v,p: 45% 25% 14% 15%
# [libx264 @ 000001e0d60d5800] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 000001e0d60d5800] ref P L0: 68.5% 26.9%  3.9%  0.8%
# [libx264 @ 000001e0d60d5800] ref B L0: 91.9%  7.9%  0.2%
# [libx264 @ 000001e0d60d5800] ref B L1: 99.7%  0.3%
# [libx264 @ 000001e0d60d5800] kb/s:11070.16
# ffmpeg version 2024-01-28-git-e0da916b8f-full_build-www.gyan.dev Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.2.0 (Rev10, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --pkg-config=pkgconf --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-sdl2 --enable-libaribb24 --enable-libaribcaption --enable-libdav1d --enable-libdavs2 --enable-libuavs3d --enable-libzvbi --enable-librav1e --enable-libsvtav1 --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxvid --enable-libaom --enable-libjxl --enable-libopenjpeg --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-ffnvcodec --enable-nvdec --enable-nvenc --enable-dxva2 --enable-d3d11va --enable-libvpl --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libcodec2 --enable-libilbc --enable-libgsm --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint
#   libavutil      58. 36.101 / 58. 36.101
#   libavcodec     60. 38.100 / 60. 38.100
#   libavformat    60. 20.100 / 60. 20.100
#   libavdevice    60.  4.100 / 60.  4.100
#   libavfilter     9. 17.100 /  9. 17.100
#   libswscale      7.  6.100 /  7.  6.100
#   libswresample   4. 13.100 /  4. 13.100
#   libpostproc    57.  4.100 / 57.  4.100
# Input #0, image2, from 'datasets/d1/stereo_post/rightEye/rightEyeInpaint%d.jpg':
#   Duration: 00:00:03.29, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 1920x1080 [SAR 1:1 DAR 16:9], 24 fps, 24 tbr, 24 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 000002865ee55900] deprecated pixel format used, make sure you did set range correctly
#     Last message repeated 1 times
# [swscaler @ 000002865ffb77c0] deprecated pixel format used, make sure you did set range correctly
#     Last message repeated 1 times
# [libx264 @ 000002865f73db00] using SAR=1/1
# [libx264 @ 000002865f73db00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 000002865f73db00] profile High, level 4.0, 4:2:0, 8-bit
# [libx264 @ 000002865f73db00] 264 - core 164 r3173 4815cca - H.264/MPEG-4 AVC codec - Copyleft 2003-2024 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=30 lookahead_threads=5 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'datasets/d1/right_eye.mp4':
#   Metadata:
#     encoder         : Lavf60.20.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 24 fps, 12288 tbn
#       Metadata:
#         encoder         : Lavc60.38.100 libx264
#       Side data:
#         cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=    0 fps=0.0 q=0.0 size=       0kB time=N/A bitrate=N/A speed=N/A
# frame=    0 fps=0.0 q=0.0 size=       0kB time=N/A bitrate=N/A speed=N/A
# frame=   23 fps= 15 q=28.0 size=    1024kB time=00:00:00.87 bitrate=9587.4kbits/s speed=0.568x
# frame=   66 fps= 32 q=-1.0 size=    3328kB time=00:00:02.66 bitrate=10223.8kbits/s speed= 1.3x
# [out#0/mp4 @ 000002865f554980] video:4341kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.040295%
# frame=   79 fps= 35 q=-1.0 Lsize=    4342kB time=00:00:03.20 bitrate=11087.3kbits/s speed=1.42x
# [libx264 @ 000002865f73db00] frame I:1     Avg QP:26.15  size:158154
# [libx264 @ 000002865f73db00] frame P:35    Avg QP:25.77  size: 76319
# [libx264 @ 000002865f73db00] frame B:43    Avg QP:28.56  size: 37551
# [libx264 @ 000002865f73db00] consecutive B-frames: 13.9% 32.9% 22.8% 30.4%
# [libx264 @ 000002865f73db00] mb I  I16..4:  2.5% 88.2%  9.3%
# [libx264 @ 000002865f73db00] mb P  I16..4:  0.3%  7.4%  1.1%  P16..4: 42.5% 30.6% 14.4%  0.0%  0.0%    skip: 3.6%
# [libx264 @ 000002865f73db00] mb B  I16..4:  0.4% 10.2%  1.8%  B16..8: 45.0% 10.9%  2.0%  direct: 3.3%  skip:26.4%  L0:42.0% L1:46.5% BI:11.6%
# [libx264 @ 000002865f73db00] 8x8 transform intra:83.7% inter:70.0%
# [libx264 @ 000002865f73db00] coded y,uvDC,uvAC intra: 85.9% 98.8% 83.0% inter: 33.6% 49.6% 9.6%
# [libx264 @ 000002865f73db00] i16 v,h,dc,p: 15% 30% 18% 38%
# [libx264 @ 000002865f73db00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 14% 19% 14%  7%  8%  7% 11%  7% 13%
# [libx264 @ 000002865f73db00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 14% 21% 10%  8% 11%  8% 11%  6% 10%
# [libx264 @ 000002865f73db00] i8c dc,h,v,p: 44% 25% 15% 16%
# [libx264 @ 000002865f73db00] Weighted P-Frames: Y:2.9% UV:2.9%
# [libx264 @ 000002865f73db00] ref P L0: 64.3% 26.6%  6.7%  1.3%  1.1%
# [libx264 @ 000002865f73db00] ref B L0: 93.3%  6.5%  0.2%
# [libx264 @ 000002865f73db00] ref B L1: 99.7%  0.3%
# [libx264 @ 000002865f73db00] kb/s:10800.59

# %% [markdown]
# ## Merge Videos and Inject Metadata
#
# Combine the left and right eye videos into an SBS video and inject 3D metadata.

# %%
left_eye_vid = dataset_directory + "left_eye.mp4"
right_eye_vid = dataset_directory + "right_eye.mp4"
output_vid = dataset_directory + "output.SBS.mp4"

# !ffmpeg -i {left_eye_vid} -i {right_eye_vid} -filter_complex "[0:v][1:v]hstack=inputs=2[v]" -map "[v]" {output_vid}
# !ffmpeg -i {output_vid} -vf "scale=2*iw:ih" -c:v libx264 -x264opts "frame-packing=3" -aspect 2:1 {final_video_filename}
# Out:
# ffmpeg version 2024-01-28-git-e0da916b8f-full_build-www.gyan.dev Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.2.0 (Rev10, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --pkg-config=pkgconf --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-sdl2 --enable-libaribb24 --enable-libaribcaption --enable-libdav1d --enable-libdavs2 --enable-libuavs3d --enable-libzvbi --enable-librav1e --enable-libsvtav1 --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxvid --enable-libaom --enable-libjxl --enable-libopenjpeg --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-ffnvcodec --enable-nvdec --enable-nvenc --enable-dxva2 --enable-d3d11va --enable-libvpl --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libcodec2 --enable-libilbc --enable-libgsm --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint
#   libavutil      58. 36.101 / 58. 36.101
#   libavcodec     60. 38.100 / 60. 38.100
#   libavformat    60. 20.100 / 60. 20.100
#   libavdevice    60.  4.100 / 60.  4.100
#   libavfilter     9. 17.100 /  9. 17.100
#   libswscale      7.  6.100 /  7.  6.100
#   libswresample   4. 13.100 /  4. 13.100
#   libpostproc    57.  4.100 / 57.  4.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'datasets/d1/left_eye.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.20.100
#   Duration: 00:00:03.29, start: 0.000000, bitrate: 11076 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1920x1080 [SAR 1:1 DAR 16:9], 11071 kb/s, 24 fps, 24 tbr, 12288 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc60.38.100 libx264
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from 'datasets/d1/right_eye.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.20.100
#   Duration: 00:00:03.29, start: 0.000000, bitrate: 10806 kb/s
#   Stream #1:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1920x1080 [SAR 1:1 DAR 16:9], 10802 kb/s, 24 fps, 24 tbr, 12288 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc60.38.100 libx264
# Stream mapping:
#   Stream #0:0 (h264) -> hstack
#   Stream #1:0 (h264) -> hstack
#   hstack:default -> Stream #0:0 (libx264)
# Press [q] to stop, [?] for help
# [libx264 @ 000002a99d7dcb00] using SAR=1/1
# [libx264 @ 000002a99d7dcb00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 000002a99d7dcb00] profile High, level 5.0, 4:2:0, 8-bit
# [libx264 @ 000002a99d7dcb00] 264 - core 164 r3173 4815cca - H.264/MPEG-4 AVC codec - Copyleft 2003-2024 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=30 lookahead_threads=5 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'datasets/d1/output.SBS.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.20.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 3840x1080 [SAR 1:1 DAR 32:9], q=2-31, 24 fps, 12288 tbn
#       Metadata:
#         encoder         : Lavc60.38.100 libx264
#       Side data:
#         cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=    0 fps=0.0 q=0.0 size=       0kB time=N/A bitrate=N/A speed=N/A
# frame=    0 fps=0.0 q=0.0 size=       0kB time=N/A bitrate=N/A speed=N/A
# frame=    0 fps=0.0 q=0.0 size=       0kB time=N/A bitrate=N/A speed=N/A
# frame=    6 fps=2.9 q=28.0 size=     768kB time=00:00:00.16 bitrate=37751.0kbits/s speed=0.0811x
# frame=   32 fps= 12 q=28.0 size=    3072kB time=00:00:01.25 bitrate=20133.0kbits/s speed=0.485x
# frame=   45 fps= 15 q=28.0 size=    4096kB time=00:00:01.79 bitrate=18728.3kbits/s speed=0.579x
# frame=   67 fps= 19 q=-1.0 size=    6400kB time=00:00:02.70 bitrate=19358.5kbits/s speed=0.751x
# [out#0/mp4 @ 000002a99ce19d40] video:7864kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.023073%
# frame=   79 fps= 21 q=-1.0 Lsize=    7866kB time=00:00:03.20 bitrate=20084.2kbits/s speed=0.843x
# [libx264 @ 000002a99d7dcb00] frame I:1     Avg QP:25.50  size:309842
# [libx264 @ 000002a99d7dcb00] frame P:41    Avg QP:25.17  size:125434
# [libx264 @ 000002a99d7dcb00] frame B:37    Avg QP:28.67  size: 70255
# [libx264 @ 000002a99d7dcb00] consecutive B-frames: 15.2% 63.3% 11.4% 10.1%
# [libx264 @ 000002a99d7dcb00] mb I  I16..4:  2.6% 89.1%  8.3%
# [libx264 @ 000002a99d7dcb00] mb P  I16..4:  0.3%  5.1%  0.6%  P16..4: 45.8% 29.9% 13.2%  0.0%  0.0%    skip: 5.0%
# [libx264 @ 000002a99d7dcb00] mb B  I16..4:  0.5% 13.6%  1.9%  B16..8: 44.5%  8.1%  1.5%  direct: 1.7%  skip:28.2%  L0:44.5% L1:46.5% BI: 9.0%
# [libx264 @ 000002a99d7dcb00] 8x8 transform intra:85.4% inter:71.3%
# [libx264 @ 000002a99d7dcb00] coded y,uvDC,uvAC intra: 81.5% 97.8% 75.7% inter: 30.4% 46.6% 6.2%
# [libx264 @ 000002a99d7dcb00] i16 v,h,dc,p: 20% 28% 20% 32%
# [libx264 @ 000002a99d7dcb00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 15% 20% 13%  7%  9%  7% 11%  7% 13%
# [libx264 @ 000002a99d7dcb00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 15% 21% 10%  8% 11%  8% 11%  6%  9%
# [libx264 @ 000002a99d7dcb00] i8c dc,h,v,p: 43% 26% 16% 16%
# [libx264 @ 000002a99d7dcb00] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 000002a99d7dcb00] ref P L0: 69.2% 27.2%  2.9%  0.6%
# [libx264 @ 000002a99d7dcb00] ref B L0: 91.3%  8.6%  0.1%
# [libx264 @ 000002a99d7dcb00] ref B L1: 99.9%  0.1%
# [libx264 @ 000002a99d7dcb00] kb/s:19569.58
# ffmpeg version 2024-01-28-git-e0da916b8f-full_build-www.gyan.dev Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12.2.0 (Rev10, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --pkg-config=pkgconf --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-sdl2 --enable-libaribb24 --enable-libaribcaption --enable-libdav1d --enable-libdavs2 --enable-libuavs3d --enable-libzvbi --enable-librav1e --enable-libsvtav1 --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxvid --enable-libaom --enable-libjxl --enable-libopenjpeg --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-ffnvcodec --enable-nvdec --enable-nvenc --enable-dxva2 --enable-d3d11va --enable-libvpl --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libcodec2 --enable-libilbc --enable-libgsm --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint
#   libavutil      58. 36.101 / 58. 36.101
#   libavcodec     60. 38.100 / 60. 38.100
#   libavformat    60. 20.100 / 60. 20.100
#   libavdevice    60.  4.100 / 60.  4.100
#   libavfilter     9. 17.100 /  9. 17.100
#   libswscale      7.  6.100 /  7.  6.100
#   libswresample   4. 13.100 /  4. 13.100
#   libpostproc    57.  4.100 / 57.  4.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'datasets/d1/output.SBS.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.20.100
#   Duration: 00:00:03.29, start: 0.000000, bitrate: 19575 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 3840x1080 [SAR 1:1 DAR 32:9], 19571 kb/s, 24 fps, 24 tbr, 12288 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc60.38.100 libx264
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0000023b0455e480] using SAR=9/32
# [libx264 @ 0000023b0455e480] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0000023b0455e480] profile High, level 5.1, 4:2:0, 8-bit
# [libx264 @ 0000023b0455e480] 264 - core 164 r3173 4815cca - H.264/MPEG-4 AVC codec - Copyleft 2003-2024 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=30 lookahead_threads=5 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 frame-packing=3 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'datasets/d1/test_SBS.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.20.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 7680x1080 [SAR 9:32 DAR 2:1], q=2-31, 24 fps, 12288 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc60.38.100 libx264
#       Side data:
#         cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=    0 fps=0.0 q=0.0 size=       0kB time=N/A bitrate=N/A speed=N/A
# frame=    0 fps=0.0 q=0.0 size=       0kB time=N/A bitrate=N/A speed=N/A
# frame=    0 fps=0.0 q=0.0 size=       0kB time=N/A bitrate=N/A speed=N/A
# frame=    0 fps=0.0 q=0.0 size=       0kB time=N/A bitrate=N/A speed=N/A
# frame=    0 fps=0.0 q=0.0 size=       0kB time=N/A bitrate=N/A speed=N/A
# frame=    0 fps=0.0 q=0.0 size=       0kB time=N/A bitrate=N/A speed=N/A
# frame=    9 fps=2.5 q=28.0 size=    1280kB time=00:00:00.29 bitrate=35952.5kbits/s speed=0.08x
# frame=   23 fps=5.5 q=28.0 size=    2816kB time=00:00:00.87 bitrate=26364.6kbits/s speed=0.211x
# frame=   32 fps=6.9 q=28.0 size=    4352kB time=00:00:01.33 bitrate=26739.0kbits/s speed=0.286x
# frame=   45 fps=8.7 q=28.0 size=    6144kB time=00:00:01.79 bitrate=28092.3kbits/s speed=0.345x
# frame=   49 fps=8.6 q=-1.0 size=    6656kB time=00:00:02.00 bitrate=27263.2kbits/s speed=0.351x
# frame=   56 fps=9.0 q=-1.0 size=    7424kB time=00:00:02.25 bitrate=27030.1kbits/s speed=0.362x
# frame=   78 fps= 12 q=-1.0 size=   11008kB time=00:00:03.16 bitrate=28477.2kbits/s speed=0.47x
# [out#0/mp4 @ 0000023b04567c00] video:11487kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.016451%
# frame=   79 fps= 11 q=-1.0 Lsize=   11489kB time=00:00:03.20 bitrate=29334.2kbits/s speed=0.456x
# [libx264 @ 0000023b0455e480] frame I:1     Avg QP:25.58  size:396250
# [libx264 @ 0000023b0455e480] frame P:42    Avg QP:24.73  size:181872
# [libx264 @ 0000023b0455e480] frame B:36    Avg QP:28.16  size:103520
# [libx264 @ 0000023b0455e480] consecutive B-frames: 16.5% 65.8%  7.6% 10.1%
# [libx264 @ 0000023b0455e480] mb I  I16..4:  6.8% 88.0%  5.1%
# [libx264 @ 0000023b0455e480] mb P  I16..4:  0.9%  6.1%  0.4%  P16..4: 57.2% 24.7%  4.3%  0.0%  0.0%    skip: 6.4%
# [libx264 @ 0000023b0455e480] mb B  I16..4:  1.6% 14.5%  1.3%  B16..8: 42.4%  5.3%  0.4%  direct: 1.5%  skip:33.1%  L0:41.5% L1:51.4% BI: 7.1%
# [libx264 @ 0000023b0455e480] 8x8 transform intra:83.8% inter:78.7%
# [libx264 @ 0000023b0455e480] coded y,uvDC,uvAC intra: 70.7% 91.8% 39.0% inter: 25.0% 42.4% 2.3%
# [libx264 @ 0000023b0455e480] i16 v,h,dc,p: 14% 52% 13% 20%
# [libx264 @ 0000023b0455e480] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 11% 41% 11%  5%  5%  2% 12%  3% 11%
# [libx264 @ 0000023b0455e480] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 10% 46%  7%  5%  6%  3% 13%  2%  8%
# [libx264 @ 0000023b0455e480] i8c dc,h,v,p: 35% 44%  8% 12%
# [libx264 @ 0000023b0455e480] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0000023b0455e480] ref P L0: 69.2% 27.1%  3.1%  0.6%
# [libx264 @ 0000023b0455e480] ref B L0: 91.2%  8.7%  0.1%
# [libx264 @ 0000023b0455e480] ref B L1: 99.9%  0.1%
# [libx264 @ 0000023b0455e480] kb/s:28585.12

# %% [markdown]
# ## Upload SBS video to Quest headset
#
# First register device connection, then push file, and lastly force the file system to update without restarting the device.

# %%
# !adb devices
# !adb push {final_video_filename} /sdcard/Movies/
# !adb shell am force-stop com.android.providers.media.module

# %% [markdown]
# ## Cleanup and Finalization
#
# (Optional) Cleanup temporary files and display/export the final video path.

# %%
# Example cleanup (adjust as needed)

#rgbd frame directories
rgbd_frames = dataset_directory + 'rgbd_in/'
#stereo directories
stereo_output_dir = dataset_directory + "stereo/"
#inpainting directories
stereo_postprocess_dir = dataset_directory + "stereo_post/"

#video directories
left_eye_vid = dataset_directory + "left_eye.mp4"
right_eye_vid = dataset_directory + "right_eye.mp4"
output_vid = dataset_directory + "output.SBS.mp4"

# delete all directories and videos
# !rm -rf {rgbd_frames}
# !rm -rf {stereo_output_dir}
# !rm -rf {stereo_postprocess_dir}
# !rm {left_eye_vid} {right_eye_vid} {output_vid}
